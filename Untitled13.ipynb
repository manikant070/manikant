# %% [markdown]
# <a href="https://colab.research.google.com/github/manikant070/manikant/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
import numpy as np

# %%
data = {
    "color":["red","green","yellow","ornage","pink"]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     color
# 0     red
# 1   green
# 2  yellow
# 3  ornage
# 4    pink

# %%
label_encoder = LabelEncoder()
df["color_label"]=label_encoder.fit_transform(df["color"])
df.head()
# Out:
#     color  color_label
# 0     red            3
# 1   green            0
# 2  yellow            4
# 3  ornage            1
# 4    pink            2

# %%
one_hot_encoder=OneHotEncoder()
one_hot_encoded=one_hot_encoder.fit_transform(df[['color']])
one_hot_encoded_df=pd.DataFrame(one_hot_encoded.toarray(),columns=one_hot_encoder.get_feature_names_out())
df=pd.concat([df,one_hot_encoded_df],axis=1)
df
# Out:
#     color  color_label  color_green  ...  color_pink  color_red  color_yellow
# 0     red            3          0.0  ...         0.0        1.0           0.0
# 1   green            0          1.0  ...         0.0        0.0           0.0
# 2  yellow            4          0.0  ...         0.0        0.0           1.0
# 3  ornage            1          0.0  ...         0.0        0.0           0.0
# 4    pink            2          0.0  ...         1.0        0.0           0.0
#
# [5 rows x 12 columns]

# %%
df.loc[[1,2],]
# Out:
#     color  color_label  color_green  ...  color_pink  color_red  color_yellow
# 1   green            0          1.0  ...         0.0        0.0           0.0
# 2  yellow            4          0.0  ...         0.0        0.0           1.0
#
# [2 rows x 12 columns]
